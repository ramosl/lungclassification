# %%
import numpy as np
INPUT_FOLDER = './database_train/'

# %%
x_train = np.load(INPUT_FOLDER + 'mini_train_x_' + str(0) + '.npy')
for i in range(1, 160):
    print(i)
    add = np.load(INPUT_FOLDER + 'mini_train_x_' + str(i) + '.npy')
    x_train = np.concatenate((x_train, add))
    print(x_train.shape)
# Out:
# 1
# (20, 64, 64, 64)
# 2
# (30, 64, 64, 64)
# 3
# (40, 64, 64, 64)
# 4
# (50, 64, 64, 64)
# 5
# (60, 64, 64, 64)
# 6
# (70, 64, 64, 64)
# 7
# (80, 64, 64, 64)
# 8
# (90, 64, 64, 64)
# 9
# (100, 64, 64, 64)
# 10
# (110, 64, 64, 64)
# 11
# (120, 64, 64, 64)
# 12
# (130, 64, 64, 64)
# 13
# (140, 64, 64, 64)
# 14
# (150, 64, 64, 64)
# 15
# (160, 64, 64, 64)
# 16
# (170, 64, 64, 64)
# 17
# (180, 64, 64, 64)
# 18
# (190, 64, 64, 64)
# 19
# (200, 64, 64, 64)
# 20
# (210, 64, 64, 64)
# 21
# (220, 64, 64, 64)
# 22
# (230, 64, 64, 64)
# 23
# (240, 64, 64, 64)
# 24
# (250, 64, 64, 64)
# 25
# (260, 64, 64, 64)
# 26
# (270, 64, 64, 64)
# 27
# (280, 64, 64, 64)
# 28
# (290, 64, 64, 64)
# 29
# (300, 64, 64, 64)
# 30
# (310, 64, 64, 64)
# 31
# (320, 64, 64, 64)
# 32
# (330, 64, 64, 64)
# 33
# (340, 64, 64, 64)
# 34
# (350, 64, 64, 64)
# 35
# (360, 64, 64, 64)
# 36
# (370, 64, 64, 64)
# 37
# (380, 64, 64, 64)
# 38
# (390, 64, 64, 64)
# 39
# (400, 64, 64, 64)
# 40
# (410, 64, 64, 64)
# 41
# ...

# %%
x_train = x_train[:1595]
print x_train.shape
# Out:
# (1595, 64, 64, 64)

# %%
np.save('x_train.npy', x_train)
